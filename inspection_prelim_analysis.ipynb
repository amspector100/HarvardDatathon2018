# %%
import pandas as pd

# %%
ch = pd.read_csv("./data/community_health.csv")

# %%
ch = pd.read_csv('./data/food_establishment_inspections.csv', engine='python')

# %%
ch.columns
# Out:
# Index(['facility', 'address', 'inspection_date', 'violation_item',
#        'violation_description', 'critical_violation', 'num_critical',
#        'num_critical_not_corrected', 'num_noncritical',
#        'local_health_department', 'county', 'facility_code', 'city', 'zipcode',
#        'municipality', 'permit_expiration_date', 'food_service_type',
#        'food_service_description', 'nys_inspection_id', 'inspection_type',
#        'inspection_comments', 'latitude', 'longitude', 'Unnamed: 23',
#        'Unnamed: 24'],
#       dtype='object')

# %%
ch.violation_description.unique().shape
ch.violation_item.unique().shape
# Out:
# (90,)

# %%
ch.loc[ch["facility"].str.contains("SCOOPS-N-MORE")]
# Out:
#                                     facility                      address  \
# 1       SCOOPS-N-MORE                         90 GLENEIDA AVENUE,  CARMEL
# 113272  SCOOPS-N-MORE                         90 GLENEIDA AVENUE,  CARMEL
# 113903  SCOOPS-N-MORE                         90 GLENEIDA AVENUE,  CARMEL
# 114096  SCOOPS-N-MORE                         90 GLENEIDA AVENUE,  CARMEL
# 114909  SCOOPS-N-MORE                         90 GLENEIDA AVENUE,  CARMEL
# 176544  SCOOPS-N-MORE                         90 GLENEIDA AVENUE,  CARMEL
# 177980  SCOOPS-N-MORE                         90 GLENEIDA AVENUE,  CARMEL
# 237357  SCOOPS-N-MORE                         90 GLENEIDA AVENUE,  CARMEL
# 237954  SCOOPS-N-MORE                         90 GLENEIDA AVENUE,  CARMEL
# 239907  SCOOPS-N-MORE                         90 GLENEIDA AVENUE,  CARMEL
# 303690  SCOOPS-N-MORE                         90 GLENEIDA AVENUE,  CARMEL
# 304069  SCOOPS-N-MORE                         90 GLENEIDA AVENUE,  CARMEL
# 304476  SCOOPS-N-MORE                         90 GLENEIDA AVENUE,  CARMEL
# 305289  SCOOPS-N-MORE                         90 GLENEIDA AVENUE,  CARMEL
# 367327  SCOOPS-N-MORE                         90 GLENEIDA AVENUE,  CARMEL
# 432774  SCOOPS-N-MORE                         90 GLENEIDA AVENUE,  CARMEL
# 494925  SCOOPS-N-MORE                         90 GLENEIDA AVENUE,  CARMEL
# 556030  SCOOPS-N-MORE                         90 GLENEIDA AVENUE,  CARMEL
# 557407  SCOOPS-N-MORE                         90 GLENEIDA AVENUE,  CARMEL
# 557789  SCOOPS-N-MORE                         90 GLENEIDA AVENUE,  CARMEL
# 622757  SCOOPS-N-MORE                         90 GLENEIDA AVENUE,  CARMEL
# 744759  SCOOPS-N-MORE                         90 GLENEIDA AVENUE,  CARMEL
# 746522  SCOOPS-N-MORE                         90 GLENEIDA AVENUE,  CARMEL
# 872777  SCOOPS-N-MORE                         90 GLENEIDA AVENUE,  CARMEL
# 874176  SCOOPS-N-MORE                         90 GLENEIDA AVENUE,  CARMEL
# 875397  SCOOPS-N-MORE                         90 GLENEIDA AVENUE,  CARMEL
# 875538  SCOOPS-N-MORE                         90 GLENEIDA AVENUE,  CARMEL
# 875598  SCOOPS-N-MORE                         90 GLENEIDA AVENUE,  CARMEL
# 875609  SCOOPS-N-MORE                         90 GLENEIDA AVENUE,  CARMEL
# 937072  SCOOPS-N-MORE                         90 GLENEIDA AVENUE,  CARMEL
# 938079  SCOOPS-N-MORE                         90 GLENEIDA AVENUE,  CARMEL
# 981562  SCOOPS-N-MORE                         90 GLENEIDA AVENUE,  CARMEL
#
#        inspection_date violation_item  \
# 1               9/9/15            10B
# 113272         5/10/11            10B
# 113903         6/24/09            14B
# 114096         7/11/12            14C
# 114909         6/22/10            11B
# 176544          5/9/07             2C
# 177980         7/11/12            11B
# 237357         6/24/09            12E
# 237954         6/22/10             8A
# 239907         6/23/14            10B
# 303690         6/24/09            14A
# 304069         9/16/13            14C
# 304476         7/11/12            15A
# 305289         4/20/16            12C
# 367327         4/20/16             8C
# 432774         8/15/17             8E
# 494925         10/6/05             5A
# 556030         9/16/13            12C
# 557407         8/15/17            13B
# 557789         8/15/17             8A
# 622757         7/11/12            12C
# 744759         6/24/09            12C
# 746522         8/15/17            12C
# 872777         5/10/11            12C
# 874176         4/20/16            13B
# 875397         9/16/13            10B
# 875538        10/11/06           None
# 875598         5/14/08           None
# 875609         9/26/06           None
# 937072         6/23/14            12C
# 938079         6/22/10            12C
# 981562         6/24/09            15B
#
#                                     violation_description  \
# 1       Non-food contact surfaces and equipment are im...
# 113272  Non-food contact surfaces and equipment are im...
# 113903  Effective measures not used to control entranc...
# 114096  Pesticide application not supervised by a cert...
# 114909  Wiping cloths dirty, not stored properly in sa...
# 176544  Cooked or prepared foods are subject to cross-...
# 177980  Wiping cloths dirty, not stored properly in sa...
# 237357  Handwashing facilities inaccessible, improperl...
# 237954  Food not protected during storage, preparation...
# 239907  Non-food contact surfaces and equipment are im...
# 303690                           Insects, rodents present
# 304069  Pesticide application not supervised by a cert...
# 304476  Floors, walls, ceilings, not smooth, properly ...
# 305289  Plumbing and sinks not properly sized, install...
# 367327  Improper use and storage of clean, sanitized e...
# 432774  Accurate thermometers not available or used to...
# 494925  Potentially hazardous foods are not kept at or...
# 556030  Plumbing and sinks not properly sized, install...
# 557407  Garbage storage areas not properly constructed...
# 557789  Food not protected during storage, preparation...
# 622757  Plumbing and sinks not properly sized, install...
# 744759  Plumbing and sinks not properly sized, install...
# 746522  Plumbing and sinks not properly sized, install...
# 872777  Plumbing and sinks not properly sized, install...
# 874176  Garbage storage areas not properly constructed...
# 875397  Non-food contact surfaces and equipment are im...
# 875538                                                NaN
# 875598                                                NaN
# 875609                                                NaN
# 937072  Plumbing and sinks not properly sized, install...
# 938079  Plumbing and sinks not properly sized, install...
# 981562  Lighting and ventilation inadequate, fixtures ...
#
#             critical_violation  num_critical  num_critical_not_corrected  \
# 1       Not Critical Violation           0.0                         0.0
# 113272  Not Critical Violation           0.0                         0.0
# 113903  Not Critical Violation           0.0                         0.0
# 114096  Not Critical Violation           0.0                         0.0
# 114909  Not Critical Violation           0.0                         0.0
# 176544      Critical Violation           1.0                         0.0
# 177980  Not Critical Violation           0.0                         0.0
# 237357  Not Critical Violation           0.0                         0.0
# 237954  Not Critical Violation           0.0                         0.0
# 239907  Not Critical Violation           0.0                         0.0
# 303690  Not Critical Violation           0.0                         0.0
# 304069  Not Critical Violation           0.0                         0.0
# 304476  Not Critical Violation           0.0                         0.0
# 305289  Not Critical Violation           0.0                         0.0
# 367327  Not Critical Violation           0.0                         0.0
# 432774  Not Critical Violation           0.0                         0.0
# 494925      Critical Violation           1.0                         0.0
# 556030  Not Critical Violation           0.0                         0.0
# 557407  Not Critical Violation           0.0                         0.0
# 557789  Not Critical Violation           0.0                         0.0
# 622757  Not Critical Violation           0.0                         0.0
# 744759  Not Critical Violation           0.0                         0.0
# 746522  Not Critical Violation           0.0                         0.0
# 872777  Not Critical Violation           0.0                         0.0
# 874176  Not Critical Violation           0.0                         0.0
# 875397  Not Critical Violation           0.0                         0.0
# 875538  Not Critical Violation           NaN                         NaN
# 875598  Not Critical Violation           NaN                         NaN
# 875609  Not Critical Violation           NaN                         NaN
# 937072  Not Critical Violation           0.0                         0.0
# 938079  Not Critical Violation           0.0                         0.0
# 981562  Not Critical Violation           0.0                         0.0
#
#         num_noncritical local_health_department     ...      \
# 1                   1.0           Putnam County     ...
# 113272              4.0           Putnam County     ...
# 113903              6.0           Putnam County     ...
# 114096              5.0           Putnam County     ...
# 114909              3.0           Putnam County     ...
# 176544              3.0           Putnam County     ...
# 177980              5.0           Putnam County     ...
# 237357              6.0           Putnam County     ...
# 237954              3.0           Putnam County     ...
# 239907              2.0           Putnam County     ...
# 303690              6.0           Putnam County     ...
# 304069              3.0           Putnam County     ...
# 304476              5.0           Putnam County     ...
# 305289              4.0           Putnam County     ...
# 367327              4.0           Putnam County     ...
# 432774              5.0           Putnam County     ...
# 494925              2.0           Putnam County     ...
# 556030              3.0           Putnam County     ...
# 557407              5.0           Putnam County     ...
# 557789              5.0           Putnam County     ...
# 622757              5.0           Putnam County     ...
# 744759              6.0           Putnam County     ...
# 746522              5.0           Putnam County     ...
# 872777              4.0           Putnam County     ...
# 874176              4.0           Putnam County     ...
# 875397              3.0           Putnam County     ...
# 875538              NaN           Putnam County     ...
# 875598              NaN           Putnam County     ...
# 875609              NaN           Putnam County     ...
# 937072              2.0           Putnam County     ...
# 938079              3.0           Putnam County     ...
# 981562              6.0           Putnam County     ...
#
#        permit_expiration_date           food_service_type  \
# 1                     3/31/18  Food Service Establishment
# 113272                3/31/18  Food Service Establishment
# 113903                3/31/18  Food Service Establishment
# 114096                3/31/18  Food Service Establishment
# 114909                3/31/18  Food Service Establishment
# 176544                3/31/18  Food Service Establishment
# 177980                3/31/18  Food Service Establishment
# 237357                3/31/18  Food Service Establishment
# 237954                3/31/18  Food Service Establishment
# 239907                3/31/18  Food Service Establishment
# 303690                3/31/18  Food Service Establishment
# 304069                3/31/18  Food Service Establishment
# 304476                3/31/18  Food Service Establishment
# 305289                3/31/18  Food Service Establishment
# 367327                3/31/18  Food Service Establishment
# 432774                3/31/18  Food Service Establishment
# 494925                3/31/18  Food Service Establishment
# 556030                3/31/18  Food Service Establishment
# 557407                3/31/18  Food Service Establishment
# 557789                3/31/18  Food Service Establishment
# 622757                3/31/18  Food Service Establishment
# 744759                3/31/18  Food Service Establishment
# 746522                3/31/18  Food Service Establishment
# 872777                3/31/18  Food Service Establishment
# 874176                3/31/18  Food Service Establishment
# 875397                3/31/18  Food Service Establishment
# 875538                3/31/18  Food Service Establishment
# 875598                3/31/18  Food Service Establishment
# 875609                3/31/18  Food Service Establishment
# 937072                3/31/18  Food Service Establishment
# 938079                3/31/18  Food Service Establishment
# 981562                3/31/18  Food Service Establishment
#
#        food_service_description nys_inspection_id inspection_type  \
# 1                    Restaurant            299840      Inspection
# 113272               Restaurant            299840      Inspection
# 113903               Restaurant            299840      Inspection
# 114096               Restaurant            299840      Inspection
# 114909               Restaurant            299840      Inspection
# 176544               Restaurant            299840      Inspection
# 177980               Restaurant            299840      Inspection
# 237357               Restaurant            299840      Inspection
# 237954               Restaurant            299840      Inspection
# 239907               Restaurant            299840      Inspection
# 303690               Restaurant            299840      Inspection
# 304069               Restaurant            299840      Inspection
# 304476               Restaurant            299840      Inspection
# 305289               Restaurant            299840      Inspection
# 367327               Restaurant            299840      Inspection
# 432774               Restaurant            299840      Inspection
# 494925               Restaurant            299840      Inspection
# 556030               Restaurant            299840      Inspection
# 557407               Restaurant            299840      Inspection
# 557789               Restaurant            299840      Inspection
# 622757               Restaurant            299840      Inspection
# 744759               Restaurant            299840      Inspection
# 746522               Restaurant            299840      Inspection
# 872777               Restaurant            299840      Inspection
# 874176               Restaurant            299840      Inspection
# 875397               Restaurant            299840      Inspection
# 875538               Restaurant            299840   Re-Inspection
# 875598               Restaurant            299840      Inspection
# 875609               Restaurant            299840      Inspection
# 937072               Restaurant            299840      Inspection
# 938079               Restaurant            299840      Inspection
# 981562               Restaurant            299840      Inspection
#
#                                       inspection_comments   latitude  \
# 1                                                     NaN  41.429351
# 113272                                                NaN  41.429351
# 113903                                                NaN  41.429351
# 114096                                                NaN  41.429351
# 114909                                                NaN  41.429351
# 176544                                                NaN  41.429351
# 177980                                                NaN  41.429351
# 237357                                                NaN  41.429351
# 237954                                                NaN  41.429351
# 239907                                                NaN  41.429351
# 303690                                                NaN  41.429351
# 304069                                                NaN  41.429351
# 304476                                                NaN  41.429351
# 305289  Informed about new e-cigarette law and given s...  41.429351
# 367327  Informed about new e-cigarette law and given s...  41.429351
# 432774                                                NaN  41.429351
# 494925                  hot dogs and cooked chicken 52 F.  41.429351
# 556030                                                NaN  41.429351
# 557407                                                NaN  41.429351
# 557789                                                NaN  41.429351
# 622757                                                NaN  41.429351
# 744759                                                NaN  41.429351
# 746522                                                NaN  41.429351
# 872777                                                NaN  41.429351
# 874176  Informed about new e-cigarette law and given s...  41.429351
# 875397                                                NaN  41.429351
# 875538                                                NaN  41.429351
# 875598                                                NaN  41.429351
# 875609                                                NaN  41.429351
# 937072                                                NaN  41.429351
# 938079                                                NaN  41.429351
# 981562                                                NaN  41.429351
#
#         longitude  Unnamed: 23 Unnamed: 24
# 1      -73.679427          NaN         NaN
# 113272 -73.679427          NaN         NaN
# 113903 -73.679427          NaN         NaN
# 114096 -73.679427          NaN         NaN
# 114909 -73.679427          NaN         NaN
# 176544 -73.679427          NaN         NaN
# 177980 -73.679427          NaN         NaN
# 237357 -73.679427          NaN         NaN
# 237954 -73.679427          NaN         NaN
# 239907 -73.679427          NaN         NaN
# 303690 -73.679427          NaN         NaN
# 304069 -73.679427          NaN         NaN
# 304476 -73.679427          NaN         NaN
# 305289 -73.679427          NaN         NaN
# 367327 -73.679427          NaN         NaN
# 432774 -73.679427          NaN         NaN
# 494925 -73.679427          NaN         NaN
# 556030 -73.679427          NaN         NaN
# 557407 -73.679427          NaN         NaN
# 557789 -73.679427          NaN         NaN
# 622757 -73.679427          NaN         NaN
# 744759 -73.679427          NaN         NaN
# 746522 -73.679427          NaN         NaN
# 872777 -73.679427          NaN         NaN
# 874176 -73.679427          NaN         NaN
# 875397 -73.679427          NaN         NaN
# 875538 -73.679427          NaN         NaN
# 875598 -73.679427          NaN         NaN
# 875609 -73.679427          NaN         NaN
# 937072 -73.679427          NaN         NaN
# 938079 -73.679427          NaN         NaN
# 981562 -73.679427          NaN         NaN
#
# [32 rows x 25 columns]

# %%
ch.loc[:20]
# Out:
#                                 facility  \
# 0          STEVIE V'S - LA ROSA PIZZERIA
# 1   SCOOPS-N-MORE
# 2   J & B LUNCHEONETTE
# 3   STOLTZFUS PASTRIES
# 4   BOATYARD GRILL
# 5   DUNKIN DONUTS
# 6   WOODSTOCK CUCINA, LLC
# 7   BREAD ALONE BAKERY
# 8                         BEAR CAFE, THE
# 9   TOUCH OF CLASS
# 10  UNION HALL INN
# 11  GRANDVIEW FARMS GOLF COURSE
# 12  DUNKIN DONUTS
# 13  ICE CREAM WORKS
# 14  Fabius Fire Department
# 15  SCARSDALE PIZZA STATION
# 16  GOTTA GETTA BAGEL
# 17  ZEN'S CHINESE FOOD
# 18  HOTEL ADAMS & HOMETOWN PIZZERIA
# 19  DRYDEN COMMUNITY CENTER CAFE
# 20  DRYDEN COMMUNITY CENTER CAFE
#
#                                               address inspection_date  \
# 0                       6318 ROBINSON ROAD,  LOCKPORT         10/3/17
# 1                         90 GLENEIDA AVENUE,  CARMEL          9/9/15
# 2                           189 ROUTE 9W,  HAVERSTRAW         4/15/10
# 3                      2325  McCULLOCH ROAD,  ROMULUS         7/12/12
# 4                  525 TAUGHANNOCK BOULEVARD,  ITHACA         8/26/11
# 5                         571-577 BROADWAY,  KINGSTON         1/26/17
# 6                      109 MILL HILL ROAD,  WOODSTOCK         4/27/15
# 7                       22 MILL HILL ROAD,  WOODSTOCK         1/11/12
# 8                      295 TINKER STREET,  BEARSVILLE         2/14/13
# 9                426 NORTH MAIN  STREET,  CANANDAIGUA         1/24/06
# 10                          2 UNION Place,  JOHNSTOWN         11/3/10
# 11                     400 HARTWELL  ROAD,  BERKSHIRE         4/12/11
# 12  5 GOLDENS BRIDGE SHOPPING CENTER,  GOLDENS BRIDGE         9/20/17
# 13                         14  GEORGE  STREET,  OWEGO          5/6/13
# 14                          7825 Main STREET,  Fabius         10/9/12
# 15                   844 SCARSDALE AVENUE,  SCARSDALE         4/27/12
# 16                           1039 BROADWAY,  WOODMERE         9/18/13
# 17                       2695 MERRICK ROAD,  BELLMORE         2/26/15
# 18                       4 WEST CHURCH STREET,  ADAMS         7/18/14
# 19                       1 WEST  MAIN STREET,  DRYDEN         7/29/15
# 20                       1 WEST  MAIN STREET,  DRYDEN         7/28/17
#
#    violation_item                              violation_description  \
# 0             15A  Floors, walls, ceilings, not smooth, properly ...
# 1             10B  Non-food contact surfaces and equipment are im...
# 2            None                                                NaN
# 3            None                                                NaN
# 4            None                                                NaN
# 5             15A  Floors, walls, ceilings, not smooth, properly ...
# 6             11C  Food contact surfaces not washed, rinsed and s...
# 7              8B  In use food dispensing utensils improperly stored
# 8             14A                           Insects, rodents present
# 9            None                                                NaN
# 10            14C  Pesticide application not supervised by a cert...
# 11           None                                                NaN
# 12            11D   Non food contact surfaces of equipment not clean
# 13           None                                                NaN
# 14            11D   Non food contact surfaces of equipment not clean
# 15           None                                                NaN
# 16             4A  Toxic chemicals are improperly labeled, stored...
# 17             4A  Toxic chemicals are improperly labeled, stored...
# 18             4A  Toxic chemicals are improperly labeled, stored...
# 19             5A  Potentially hazardous foods are not kept at or...
# 20             5A  Potentially hazardous foods are not kept at or...
#
#         critical_violation  num_critical  num_critical_not_corrected  \
# 0   Not Critical Violation           0.0                         0.0
# 1   Not Critical Violation           0.0                         0.0
# 2   Not Critical Violation           0.0                         0.0
# 3   Not Critical Violation           0.0                         0.0
# 4   Not Critical Violation           0.0                         0.0
# 5   Not Critical Violation           0.0                         0.0
# 6   Not Critical Violation           0.0                         0.0
# 7   Not Critical Violation           1.0                         0.0
# 8   Not Critical Violation           0.0                         0.0
# 9   Not Critical Violation           NaN                         NaN
# 10  Not Critical Violation           0.0                         0.0
# 11  Not Critical Violation           0.0                         0.0
# 12  Not Critical Violation           0.0                         0.0
# 13  Not Critical Violation           0.0                         0.0
# 14  Not Critical Violation           0.0                         0.0
# 15  Not Critical Violation           0.0                         0.0
# 16      Critical Violation           1.0                         0.0
# 17      Critical Violation           2.0                         0.0
# 18      Critical Violation           1.0                         0.0
# 19      Critical Violation           1.0                         0.0
# 20      Critical Violation           1.0                         0.0
#
#     num_noncritical    local_health_department     ...      \
# 0               3.0             Niagara County     ...
# 1               1.0              Putnam County     ...
# 2               0.0            Rockland County     ...
# 3               0.0             Seneca  County     ...
# 4               0.0            Tompkins County     ...
# 5               4.0              Ulster County     ...
# 6               9.0              Ulster County     ...
# 7               4.0              Ulster County     ...
# 8              20.0              Ulster County     ...
# 9               NaN     Geneva District Office     ...
# 10              2.0   Herkimer District Office     ...
# 11              0.0               Tioga County     ...
# 12              3.0         Westchester County     ...
# 13              0.0               Tioga County     ...
# 14              1.0            Onondaga County     ...
# 15              0.0         Westchester County     ...
# 16              8.0             Nassau  County     ...
# 17              7.0             Nassau  County     ...
# 18              9.0  Watertown District Office     ...
# 19              1.0            Tompkins County     ...
# 20              0.0            Tompkins County     ...
#
#    permit_expiration_date           food_service_type  \
# 0                10/31/18  Food Service Establishment
# 1                 3/31/18  Food Service Establishment
# 2                 4/30/18  Food Service Establishment
# 3                 7/30/18  Food Service Establishment
# 4                 3/31/18  Food Service Establishment
# 5                 2/28/18  Food Service Establishment
# 6                 2/28/18  Food Service Establishment
# 7                 2/28/18  Food Service Establishment
# 8                 2/28/18  Food Service Establishment
# 9                 4/30/18  Food Service Establishment
# 10               12/31/17  Food Service Establishment
# 11                9/30/17  Food Service Establishment
# 12                7/31/18  Food Service Establishment
# 13               10/31/16  Food Service Establishment
# 14                1/31/19  Food Service Establishment
# 15                1/31/19  Food Service Establishment
# 16               10/31/17  Food Service Establishment
# 17                4/30/18  Food Service Establishment
# 18               12/31/19  Food Service Establishment
# 19                3/31/18  Food Service Establishment
# 20                3/31/18  Food Service Establishment
#
#          food_service_description nys_inspection_id inspection_type  \
# 0   Restaurant/Catering Operation            286815      Inspection
# 1                      Restaurant            299840      Inspection
# 2      Food Service Establishment            303561      Inspection
# 3                          Bakery            308241      Inspection
# 4   Restaurant/Catering Operation            313774   Re-Inspection
# 5      Food Service Establishment            316462      Inspection
# 6      Food Service Establishment            317327      Inspection
# 7      Food Service Establishment            316695      Inspection
# 8      Food Service Establishment            316696      Inspection
# 9      Food Service Establishment            420878      Inspection
# 10                     Restaurant            337822      Inspection
# 11     Food Service Establishment            430604      Inspection
# 12     Food Service Establishment            553825      Inspection
# 13                Frozen Desserts            831532      Inspection
# 14     Food Service Establishment            541950      Inspection
# 15     Food Service Establishment            536234   Re-Inspection
# 16                   Delicatessen            573770      Inspection
# 17     Food Service Establishment            816465      Inspection
# 18                     Restaurant            546279      Inspection
# 19  Restaurant/Catering Operation            599284      Inspection
# 20  Restaurant/Catering Operation            599284      Inspection
#
#                                   inspection_comments   latitude  longitude  \
# 0   Restrooms: OK\nFood Testing Thermometers: OK\n...  43.124090 -78.736710
# 1                                                 NaN  41.429351 -73.679427
# 2                                                 NaN  41.198585 -73.981861
# 3                                                 NaN  42.786649 -76.809727
# 4                                                 NaN  42.442929 -76.513121
# 5   Walk in freezer at 0 degrees F.  Handwash stat...  41.928899 -74.002976
# 6                                                 NaN  42.037124 -74.110615
# 7                                                 NaN  42.040633 -74.117516
# 8                                                 NaN        NaN        NaN
# 9                                                 NaN  42.900890 -77.290872
# 10                                                NaN  43.006234 -74.367175
# 11                                                NaN  42.317652 -76.112406
# 12  Measured cold holding temperatures adequate at...        NaN        NaN
# 13                                                NaN        NaN        NaN
# 14                                                NaN        NaN        NaN
# 15                                                NaN  40.986091 -73.808930
# 16                                                NaN  40.631449 -73.707302
# 17                                                NaN  40.662857 -73.529327
# 18                                                NaN  43.809303 -76.024607
# 19  Part I Critical Item Violation 5A\nPart II Blu...  42.490502 -76.297760
# 20  Part I Critical Item Violation 5A\nNo Part II ...  42.490502 -76.297760
#
#     Unnamed: 23 Unnamed: 24
# 0           NaN         NaN
# 1           NaN         NaN
# 2           NaN         NaN
# 3           NaN         NaN
# 4           NaN         NaN
# 5           NaN         NaN
# 6           NaN         NaN
# 7           NaN         NaN
# 8           NaN         NaN
# 9           NaN         NaN
# 10          NaN         NaN
# 11          NaN         NaN
# 12          NaN         NaN
# 13          NaN         NaN
# 14          NaN         NaN
# 15          NaN         NaN
# 16          NaN         NaN
# 17          NaN         NaN
# 18          NaN         NaN
# 19          NaN         NaN
# 20          NaN         NaN
#
# [21 rows x 25 columns]

# %%
by_name = ch.groupby("facility").count()

# %%
trimmed = by_name.drop(columns=['inspection_date', 'violation_item',
       'violation_description', 'critical_violation', 'num_critical',
       'num_critical_not_corrected', 'num_noncritical',
       'local_health_department', 'county', 'facility_code', 'city', 'zipcode',
       'municipality', 'permit_expiration_date', 'food_service_type',
       'food_service_description', 'nys_inspection_id', 'inspection_type',
       'inspection_comments', 'latitude', 'longitude', 'Unnamed: 23',
       'Unnamed: 24'])
trimmed
# Out:
#                                        address
# facility
#  BEJING HOUSE                               14
#  BELLMORE-MERRICK CSD  MEPHAM H S           16
#  BELLMORE-MERRICK CSD  SH CALHOUN HS        11
#  FU YA                                      20
#  NEW NO. 1 CHINESE RESTAURANT                3
# "AIM" 2 PLEASE                               4
# #1 CHINESE RESTAURANT                      173
# #1 King's Buffet, A                        190
# #121 RESTAURANT                            203
# & A DELI, A                                 50
# & G TEXAS WEINERS, A                        41
# & J CHINA STAR, A                           15
# & J ICE CREAM & FOOD, A                     10
# & J LUNCHEONETTE, A                          9
# & J'S SUBS, PIZZA AND GRILL, A              12
# & M ASIAN FOOD, A                            7
# & M DELI, A                                 91
# & P BAR, LLC, A                              1
# & S FINE FOODS OF MILLWOOD, A               54
# & S FINE FOODS(ITALIAN PORK STORE), A       60
# & S FINE FOODS, A                          123
# & S MARKETPLACE, A                         100
# & S QUZINE, A                               60
# & V PIZZERIA, A                            141
# & W 90090, A                                13
# & W FAMILY RESTAURANT, A                    30
# & W RESTAURANT, A                           41
# & W ROOT BEER-LAKE GEORGE, A                52
# 1 2 3 FOOD STOP                              8
# 1 EURO PIZZERIA                             72
# ...                                        ...
# ZOE'S ICE CREAM BARN                         7
# ZOILA'S                                     25
# ZOLLER ELEMENTARY SCHOOL                    31
# ZONA                                        27
# ZONA ROSA                                   25
# ZONTA HOUSE - EZC CORP.                      2
# ZOOM FLUME WATER PARK                       87
# ZORADORA'S                                  12
# ZORN'S FAMOUS CHICKEN & RIBS                65
# ZORN'S POULTRY FARMS                        74
# ZOU CHINESE CUISINE                          7
# ZOU JAPANESE & CHINESE CUISINE, INC.        18
# ZOUP                                         5
# ZOUP !     STORE #183                        3
# ZUGIBE VINEYARDS                             7
# ZULIMAR RESTAURANT                          23
# ZUPPA                                       77
# ZWE KA BIN                                  22
# ZWEIGLES NATION/CAPELLI SPORT STADIU         9
# Zachary's Original                          77
# Zebb's Deluxe Grill & Bar                   58
# Zion Church                                 20
# Zippy's                                      3
# b.good                                       1
# c. 1820 House (The)                         45
# i BAGEL CAFE                                61
# i DOG MACARONI COMPANY                       2
# iPHO                                        11
# iPIC THEATER                                 4
# niagara county youth bureau                245
#
# [32291 rows x 1 columns]

# %%
print(trimmed.var())
print(trimmed.mean)
# Out:
# address    2957.309104
# dtype: float64
# <bound method DataFrame.mean of                                        address
# facility
#  BEJING HOUSE                               14
#  BELLMORE-MERRICK CSD  MEPHAM H S           16
#  BELLMORE-MERRICK CSD  SH CALHOUN HS        11
#  FU YA                                      20
#  NEW NO. 1 CHINESE RESTAURANT                3
# "AIM" 2 PLEASE                               4
# #1 CHINESE RESTAURANT                      173
# #1 King's Buffet, A                        190
# #121 RESTAURANT                            203
# & A DELI, A                                 50
# & G TEXAS WEINERS, A                        41
# & J CHINA STAR, A                           15
# & J ICE CREAM & FOOD, A                     10
# & J LUNCHEONETTE, A                          9
# & J'S SUBS, PIZZA AND GRILL, A              12
# & M ASIAN FOOD, A                            7
# & M DELI, A                                 91
# & P BAR, LLC, A                              1
# & S FINE FOODS OF MILLWOOD, A               54
# & S FINE FOODS(ITALIAN PORK STORE), A       60
# & S FINE FOODS, A                          123
# & S MARKETPLACE, A                         100
# & S QUZINE, A                               60
# & V PIZZERIA, A                            141
# & W 90090, A                                13
# & W FAMILY RESTAURANT, A                    30
# & W RESTAURANT, A                           41
# & W ROOT BEER-LAKE GEORGE, A                52
# 1 2 3 FOOD STOP                              8
# 1 EURO PIZZERIA                             72
# ...                                        ...
# ZOE'S ICE CREAM BARN                         7
# ZOILA'S                                     25
# ZOLLER ELEMENTARY SCHOOL                    31
# ZONA                                        27
# ZONA ROSA                                   25
# ZONTA HOUSE - EZC CORP.                      2
# ZOOM FLUME WATER PARK                       87
# ZORADORA'S                                  12
# ZORN'S FAMOUS CHICKEN & RIBS                65
# ZORN'S POULTRY FARMS                        74
# ZOU CHINESE CUISINE                          7
# ZOU JAPANESE & CHINESE CUISINE, INC.        18
# ZOUP                                         5
# ZOUP !     STORE #183                        3
# ZUGIBE VINEYARDS                             7
# ZULIMAR RESTAURANT                          23
# ZUPPA                                       77
# ZWE KA BIN                                  22
# ZWEIGLES NATION/CAPELLI SPORT STADIU         9
# Zachary's Original                          77
# Zebb's Deluxe Grill & Bar                   58
# Zion Church                                 20
# Zippy's                                      3
# b.good                                       1
# c. 1820 House (The)                         45
# i BAGEL CAFE                                61
# i DOG MACARONI COMPANY                       2
# iPHO                                        11
# iPIC THEATER                                 4
# niagara county youth bureau                245
#
# [32291 rows x 1 columns]>

# %%
type(by_name)
# Out:
# pandas.core.frame.DataFrame

# %%
by_address = ch.groupby("address").count()

# %%
trimmed_address = by_address.drop(columns=['inspection_date', 'violation_item',
       'violation_description', 'critical_violation', 'num_critical',
       'num_critical_not_corrected', 'num_noncritical',
       'local_health_department', 'county', 'facility_code', 'city', 'zipcode',
       'municipality', 'permit_expiration_date', 'food_service_type',
       'food_service_description', 'nys_inspection_id', 'inspection_type',
       'inspection_comments', 'latitude', 'longitude', 'Unnamed: 23',
       'Unnamed: 24'])

# %%
print(trimmed_address)
print(trimmed_address.var())
# Out:
#                                               facility
# address
# "B" CLUSTER,  GARDEN CITY                            4
# #1 CHURCH STREET,  HYDE PARK                        26
# #1 OSCAWANA LAKE  ROAD,  PUTNAM VALLEY               4
# #2-20 RENSSELAER STREET,  ALBANY                     8
# #309 CLIFTON PARK CENTER ROAD,  CLIFTON PARK         3
# #36 AVENUE M,  MECHANICVILLE                         1
# #5 43 MALL,  W. SAND LAKE                           11
# #C202 - 1 CROSSGATES MALL ROAD,  ALBANY             11
# . JONES BEACH STATE PARK,  WANTAGH                   9
# 0369 ROUTES 5 AND 20,  WATERLOO                     16
# 0379  WATERLOO-GENEVA ROAD,  WATERLOO               14
# 0446 WATERLOO GENEVA ROAD,  WATERLOO                 2
# 1  CHAMPIONSHIP WAY,  WHITESBORO                     1
# 1  ELKS LANE,  SARATOGA SPRINGS                     21
# 1  FERRIS HILLS,  CANANDAIGUA                       46
# 1  GARFIELD STREET,  WAVERLY                        32
# 1  GOODMAN  STREET,  GENEVA                          9
# 1  HAMILTON  ROAD,  FAIRPORT NY                     14
# 1  HOMEWOOD  AVENUE,  NEWBURGH                       1
# 1  Katz  ROAD,  Fallsburg                           40
# 1  MUSTANG HILL,  MARCELLUS                         59
# 1  OWENS  ROAD,  NEWBURGH                           14
# 1  PARK  PLACE,  NEWBURGH                           68
# 1  PARK PLACE,  BRONXVILLE                         164
# 1  RYAN DRIVE,  GENESEO                              6
# 1  SOUTH WOODS ROAD,  WOODBURY                       3
# 1  SUNRISE MALL,  MASSAPEQUA                         1
# 1 + 1A RYE RIDGE PLAZA,  RYE BROOK                  10
# 1 A GRASSFIELD  ROAD,  GREAT NECK                    8
# 1 ACADEMIC DRIVE,  CORNING                           6
# ...                                                ...
# WEST TENTH & UTICA STREET,  OSWEGO                  58
# WESTCHESTER AVENUE,  BUCHANAN                       25
# WESTCHESTER MEDICAL CENTER ROAD,  VALHALLA          44
# WESTCHESTER MEDICAL CENTER,  VALHALLA               42
# WESTERLY ROAD,  OSSINING                            24
# WEYMAN AVENUE,  NEW ROCHELLE                        93
# WHITFIELD ROAD,  ACCORD                             21
# WILDER ROAD,  WARSAW                                13
# WILLARD STRAIGHT HALL,  ITHACA                      37
# WILLIAM GILLARD DRIVE,  FULTON                      16
# WILLIAM STREET,  WHITEHALL                           9
# WILLOW  STREET,  ROSLYN HEIGHTS                      6
# WILLOW GROVE ROAD,  STONY POINT                     59
# WILLOW GROVE ROAD,  THIELLS                          1
# WILSON ROAD,  CENTRAL SQUARE                        13
# WINNE AVENUE,  RAVENA                               12
# WINTER CLOVE ROAD,  ROUND TOP                       28
# WISNER  AVENUE,  MIDDLETOWN                          1
# WOODLAWN & PARTRIDGE STREET,  ALBANY                13
# Watson Blvd - Davis Field,  ENDICOTT                 3
# Watson Blvd - Logan Field,  ENDICOTT                 5
# West Middle AVENUE,  BINGHAMTON                     32
# West Rd.,  CORTLAND                                 67
# Weston ROAD,  NEW HARTFORD                          16
# Wilcox ROAD,  Leroy                                  8
# Woodlawn DRIVE,  VESTAL                             17
# Woods Road Park,  Solvay                            16
# XAVIER DRIVE,  YONKERS                               7
# ZENA HIGHWOODS ROAD,  WOODSTOCK                     34
# ZOAR AVENUE,  ALBANY                                15
#
# [32831 rows x 1 columns]
# facility    1154.981608
# dtype: float64

# %%
print(trimmed_address["facility"].mean())
print(trimmed["address"].mean())
# Out:
# 30.84807042124821
# 31.363940416834414
