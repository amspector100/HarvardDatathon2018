10110.0, 10111.0, 10112.0, 10115.0, 10118.0, 10119.0, 10121.0, 10123.0, 10128.0, 10153.0, 10154.0, 11691.0, 11692.0, 11693.0, 11694.0, 10155.0, 10158.0, 11697.0, 10165.0, 10167.0, 10168.0, 10169.0, 10170.0, 10171.0, 10172.0, 10173.0, 10174.0, 10176.0, 11201.0, 10178.0, 11203.0, 11204.0, 11205.0, 11206.0, 11207.0, 11208.0, 11209.0, 11210.0, 11211.0, 11212.0, 11213.0, 11214.0, 11215.0, 11216.0, 11217.0, 11218.0, 11219.0, 11220.0, 11221.0, 11222.0, 11223.0, 11224.0, 11225.0, 11226.0, 11228.0, 11229.0, 11230.0, 11231.0, 11232.0, 11233.0, 11234.0, 11235.0, 11236.0, 11237.0, 11238.0, 11239.0, 11241.0, 11242.0, 11249.0}

# %%
from uszipcode import ZipcodeSearchEngine
import numpy
search = ZipcodeSearchEngine()
nyc_zip_set = set()
for zipcode in zipset:
    if search.by_zipcode(int(zipcode))["City"] == "New York":
        nyc_zip_set.add(zipcode)

# %%
nyc_zip_set = {10001.0, 10002.0, 10003.0, 10004.0, 10005.0, 10006.0, 10007.0, 10009.0, 10010.0, 10011.0, 10012.0, 10013.0, 10014.0, 10016.0, 10017.0, 10018.0, 10019.0, 10020.0, 10021.0, 10022.0, 10023.0, 10024.0, 10025.0, 10026.0, 10027.0, 10028.0, 10029.0, 10030.0, 10031.0, 10032.0, 10033.0, 10034.0, 10035.0, 10036.0, 10037.0, 10038.0, 10039.0, 10040.0, 10044.0, 10065.0, 10069.0, 10075.0, 10103.0, 10110.0, 10111.0, 10112.0, 10115.0, 10119.0, 10128.0, 10153.0, 10154.0, 10165.0, 10167.0, 10168.0, 10169.0, 10170.0, 10171.0, 10172.0, 10173.0, 10174.0, 10177.0, 10271.0, 10279.0, 10280.0, 10282.0}

# %%
ziplist = list(nyc_zip_set)

# %%
cleaned_data = data.loc[data["ZIPCODE"].isin(nyc_zip_set)]

# %%
cleaned_data.columns
# Out:
# Index(['CAMIS', 'DBA', 'BORO', 'BUILDING', 'STREET', 'ZIPCODE', 'PHONE',
#        'CUISINE DESCRIPTION', 'INSPECTION DATE', 'ACTION', 'VIOLATION CODE',
#        'VIOLATION DESCRIPTION', 'CRITICAL FLAG', 'SCORE', 'GRADE',
#        'GRADE DATE', 'RECORD DATE', 'INSPECTION TYPE'],
#       dtype='object')

# %%
final_data = cleaned_data.drop_duplicates(['CAMIS', 'GRADE DATE'])

# %%
print(cleaned_data.shape)
print(final_data.shape)
# Out:
# (145306, 18)
# (39718, 18)

# %%
final_data[:20]
# Out:
#        CAMIS                            DBA       BORO BUILDING  \
# 2   50059677                  D FRUIT OPPIA  MANHATTAN      518
# 5   41267359                      MADANGSUI  MANHATTAN       35
# 8   40524778          MCQUAIDS PUBLIC HOUSE  MANHATTAN      589
# 10  50016151  UPPER STORY BY CHARLIE PALMER  MANHATTAN      979
# 14  41692397                  LA BELLA VITA  MANHATTAN      163
# 15  50019124                       RAMEN-YA  MANHATTAN      133
# 21  50017538               ELI'S ESSENTIALS  MANHATTAN     1390
# 22  41024174            CAMARADAS EL BARRIO  MANHATTAN     2241
# 30  50048433       FLUFFY'S CAFE & PIZZERIA  MANHATTAN      370
# 32  50048711        LIMON JUNGLE RESTAURANT  MANHATTAN        1
# 33  40901832                     TAL BAGELS  MANHATTAN     1228
# 34  40374266                     KASTELI II  MANHATTAN      372
# 35  40566335        CARRY ON TEA & SYMPATHY  MANHATTAN      110
# 38  40510605                  HAMILTON DELI  MANHATTAN     1129
# ...

# %%
inspection_counts_prelim = final_data.groupby(['CAMIS']).size()

# %%
inspection_counts_prelim.mean()
# Out:
# 3.859113874854256

# %%
inspection_counts_prelim.plot(kind= "hist")
